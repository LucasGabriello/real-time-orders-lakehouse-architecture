# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/orders_volume/landing")
dbutils.fs.mkdirs("/Volumes/workspace/default/orders_volume/bronze")
dbutils.fs.mkdirs("/Volumes/workspace/default/orders_volume/silver")
dbutils.fs.mkdirs("/Volumes/workspace/default/orders_volume/gold")
dbutils.fs.mkdirs("/Volumes/workspace/default/orders_volume/checkpoints")
dbutils.fs.mkdirs("/Volumes/workspace/default/orders_volume/source")
